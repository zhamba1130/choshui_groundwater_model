# %%
import flopy
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from skimage.draw import polygon

# %%
path = 'choshui_original.bas'      #boundary檔
l=0
bound = []
layer = []
b = []

with open(path) as f:
    for line in f.readlines():
        if 'Layer' in line:
            l += 1
        
        elif l>0:
            s = line.split(' ')

            for j in s:
                if j != '' :
                    b.append(int(j)) 

            if len(b) >= 309:
                layer.append(b)
                b=[]

            if len(layer) >= 400:
                bound.append(layer)
                layer = []

            if len(bound) == 9:
                break

bound = np.array(bound)
print(bound.shape)
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (9, 400, 309)

# %%
cmap = colors.ListedColormap(['blue','white','grey'])    #-1, 0, 1 

plt.figure(figsize=(9,12))
plt.pcolor(bound[0][::-1], cmap=cmap, edgecolors='black')
plt.show()
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vertices = np.array([[170,200],[168,195],[168,190],[167,180],[165,172],[160,170],[155,168],[148,166],[141,168],[136,170],
                     [131,172],[125,175],[122,178],[120,185],[118,190],[115,195],[106,192],[102,190],[95,189],[88,188],[84,189],
                     [80,190],[80,270],[170,270]
                    ])
rr,cc = polygon(vertices[:,0], vertices[:,1], bound[0][::-1].shape)

wel_list = []

for i in range(len(rr)):
    if bound[1][399-rr[i]][cc[i]] == 1:
        bound[0][399-rr[i]][cc[i]] = 2
        wel_list.append([399-rr[i],cc[i]])
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
cmap = colors.ListedColormap(['blue','white','grey','red'])

plt.figure(figsize=(9,12))
plt.pcolor(bound[0][::-1], cmap=cmap, edgecolors='black')
plt.show()
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(len(wel_list))
print(wel_list)
# Out:
# 2151
# ...

# %%
for i in wel_list:
    i.append(0)
    i.insert(0, 0)
    
print(wel_list)
# Out:
# [[0, 318, 190, 0], [0, 317, 190, 0], [0, 316, 190, 0], [0, 315, 189, 0], [0, 315, 190, 0], [0, 315, 191, 0], [0, 314, 189, 0], [0, 314, 190, 0], [0, 314, 191, 0], [0, 313, 189, 0], [0, 313, 190, 0], [0, 313, 191, 0], [0, 313, 192, 0], [0, 312, 189, 0], [0, 312, 190, 0], [0, 312, 191, 0], [0, 312, 192, 0], [0, 311, 188, 0], [0, 311, 189, 0], [0, 311, 190, 0], [0, 311, 191, 0], [0, 311, 192, 0], [0, 311, 193, 0], [0, 310, 189, 0], [0, 310, 190, 0], [0, 310, 191, 0], [0, 310, 192, 0], [0, 310, 193, 0], [0, 309, 189, 0], [0, 309, 190, 0], [0, 309, 191, 0], [0, 309, 192, 0], [0, 309, 193, 0], [0, 309, 194, 0], [0, 308, 189, 0], [0, 308, 190, 0], [0, 308, 191, 0], [0, 308, 192, 0], [0, 308, 193, 0], [0, 308, 194, 0], [0, 308, 195, 0], [0, 307, 189, 0], [0, 307, 190, 0], [0, 307, 191, 0], [0, 307, 192, 0], [0, 307, 193, 0], [0, 307, 194, 0], [0, 307, 195, 0], [0, 307, 196, 0], [0, 306, 189, 0], [0, 306, 190, 0], [0, 306, 191, 0], [0, 306, 192, 0], [0, 306, 193, 0], [0, 306, 194, 0], [0, 306
# ...

# %%
obs_wels = [[82,82], [109,131], [175,74], [111,195], [148,238], [170,195], [246,177], [213,151], [156,174], [145,145]]
for o in obs_wels:
    bound[0][399-o[0]][o[1]] = 3

cmap = colors.ListedColormap(['blue','white','grey','red','yellow'])

plt.figure(figsize=(18,24))
plt.pcolor(bound[0][::-1], cmap=cmap, edgecolors='black')
plt.show()
# Out:
# c:\users\johnny\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
